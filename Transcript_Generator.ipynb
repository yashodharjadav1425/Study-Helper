# %%
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-yr9pzujg
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-yr9pzujg
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 11.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...

# %%
# !whisper "audio_name.mp3" --model medium
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:05.720]  Imagine a regular day in your life. You wake up in the morning to the automatic
# [00:05.720 --> 00:10.800]  curtains and lighting in your room controlled by AI. Your alarm rings based
# [00:10.800 --> 00:15.720]  on your schedule, in your calendar, and the time you slept at. All through the
# [00:15.720 --> 00:20.640]  night, your AC was adjusting to suit your body temperature. Now that you are up,
# [00:20.640 --> 00:25.560]  every single activity around you is driven through machine learning. Your
# [00:25.560 --> 00:29.760]  mobile phone has organized news for you based on your interests. This uses
# ...

# %%
# !pip install moviepy

# %%
import moviepy.editor

video = moviepy.editor.VideoFileClip('input2.mp4')

audio = video.audio

audio.write_audiofile('audio_name.mp3')
# Out:
# ...
# chunk:   1%|          | 152/17986 [40:00<00:22, 794.35it/s, now=None]
# MoviePy - Writing audio in audio_name.mp3
# chunk:   0%|          | 0/6121 [00:00<?, ?it/s, now=None]
#
# chunk:   1%|          | 44/6121 [00:00<00:13, 438.78it/s, now=None]
#
# chunk:   1%|▏         | 89/6121 [00:00<00:14, 429.44it/s, now=None]
#
# chunk:   2%|▏         | 132/6121 [00:00<00:15, 383.31it/s, now=None]
#
# chunk:   3%|▎         | 171/6121 [00:00<00:16, 361.98it/s, now=None]
#
# chunk:   4%|▎         | 216/6121 [00:00<00:15, 385.87it/s, now=None]
#
# chunk:   4%|▍         | 261/6121 [00:00<00:14, 396.86it/s, now=None]
#
# chunk:   5%|▍         | 306/6121 [00:00<00:14, 398.09it/s, now=None]
#
# chunk:   6%|▌         | 351/6121 [00:00<00:14, 409.01it/s, now=None]
#
# chunk:   6%|▋         | 396/6121 [00:00<00:13, 411.77it/s, now=None]
#
# chunk:   7%|▋         | 438/6121 [00:01<00:14, 400.80it/s, now=None]
#
# chunk:   8%|▊         | 479/6121 [00:01<00:14, 401.78it/s, now=None]
#
# ...
